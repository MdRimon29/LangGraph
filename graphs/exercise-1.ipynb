# %%
from typing import TypedDict, Dict
from langgraph.graph import StateGraph, START, END

# %%
class AgentState(TypedDict):
    message: str

def given_input(state: AgentState)-> AgentState:
    """Appriciation to a person."""
    state['message'] = state['message'] + ", you are doing amazing job learning LangGraph!"
    return state

# %%
graph = StateGraph(AgentState)

graph.add_node('praise someone', given_input)

graph.set_entry_point('praise someone')
graph.set_finish_point('praise someone')

agent = graph.compile()
agent

# %%
result = agent.invoke({'message': 'Rimon'})
result['message']
# Out:
# 'Rimon, you are doing amazing job learning LangGraph!'
