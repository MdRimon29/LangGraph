# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv
import os

# %%
load_dotenv()

model = ChatGroq(
    model="openai/gpt-oss-120b",
    api_key= os.getenv("GROQ_API_KEY"),
    temperature=0,
)

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': '**Blog Title:** *The Rise of AI in India: Opportunities, Challenges, and the Road Ahead*\n\n---\n\n## 1. Introduction  \n- **Hook:** A striking statistic or anecdote (e.g., “India is projected to become the world’s third‑largest AI market by 2027.”)  \n- **Why It Matters:** Briefly explain AI’s global impact and why India’s trajectory is uniquely significant.  \n- **Thesis Statement:** Outline the blog’s focus – exploring the drivers, key players, sectoral adoption, policy landscape, challenges, and future outlook of AI in India.\n\n---\n\n## 2. Historical Context  \n### 2.1 Early Foundations  \n- 1950s‑70s: Pioneering research at IITs & ISI Kolkata.  \n- 1980s‑90s: Government-sponsored projects (e.g., C-DAC’s “Artificial Intelligence” labs).  \n\n### 2.2 The Turn‑of‑the‑Century Shift  \n- Emergence of IT outsourcing and software services.  \n- First wave of AI startups (e.g., Niramai, Haptik).  \n\n### 2.3 Post‑2015 Acceleration  \n- Global AI boom + Indian government’s “Digital India” push.  \n- Availability of cheap cloud compute and open‑source frameworks.\n\n---\n\n## 3. Key Drivers Behind the AI Surge  \n| Driver | Description | Illustrative Example |\n|--------|-------------|----------------------|\n| **Demographic Dividend** | Young, tech‑savvy workforce; large talent pool. | 2.5\u202fM+ engineering graduates annually. |\n| **Data Abundance** | Massive mobile penetration, digital payments, and government data portals. | Unified Payments Interface (UPI) generates billions of transactions daily. |\n| **Policy & Funding** | National AI Strategy, AI research grants, startup incentives. | NITI Aayog’s “AI for All” roadmap; INR\u202f10,000\u202fcr AI fund. |\n| **Corporate & Startup Ecosystem** | Presence of global tech giants and vibrant VC scene. | Google AI Research Center Bengaluru; $2\u202fbn AI‑focused VC deals in 2023. |\n| **Infrastructure** | Cloud, 5G rollout, edge computing nodes. | Reliance Jio’s 5G network enabling real‑time AI services. |\n\n---\n\n## 4. Major Players & Ecosystem  \n### 4.1 Government & Public Institutions  \n- **NITI Aayog** – AI strategy & task forces.  \n- **DRDO & ISRO** – AI for defense, satellite imagery.  \n- **IITs & IIMs** – AI research labs, interdisciplinary programs.  \n\n### 4.2 Corporate Leaders  \n- **Tech Giants:** Google, Microsoft, Amazon, IBM (AI research labs in Bengaluru, Hyderabad).  \n- **Indian Conglomerates:** Tata Consultancy Services, Infosys, Wipro (AI‑driven consulting & products).  \n\n### 4.3 Startup Landscape  \n- **Healthcare:** Niramai (breast cancer screening), Qure.ai (radiology).  \n- **FinTech:** Razorpay, Paytm (fraud detection, credit scoring).  \n- **Agriculture:** CropIn, Stellapps (precision farming).  \n- **Enterprise AI:** Mad Street Den, Uniphore (NLP & voice AI).  \n\n### 4.4 Funding & Investment Trends  \n- Year‑on‑year VC/PE AI funding growth chart.  \n- Notable exits & IPOs (e.g., Haptik acquisition by Reliance Jio).  \n\n---\n\n## 5. Sector‑Specific AI Adoption  \n\n| Sector | Use‑Cases | Impact Metrics | Notable Indian Initiatives |\n|--------|----------|----------------|----------------------------|\n| **Healthcare** | Diagnostic imaging, tele‑medicine bots, drug discovery | 30% reduction in diagnostic time; 20% cost savings | Niramai, HealthifyMe, AI‑enabled Ayushman Bharat portals |\n| **Finance & Banking** | Credit scoring, fraud detection, robo‑advisors | 40% drop in false‑positive fraud alerts | Paytm, Razorpay, Axis Bank’s AI‑driven chatbots |\n| **Agriculture** | Crop disease detection, yield prediction, supply‑chain optimization | 15% yield increase for pilot farms | CropIn, Stellapps, Microsoft’s AI for Earth India |\n| **Education** | Adaptive learning platforms, automated grading, language translation | 25% improvement in student engagement scores | BYJU’S AI, Embibe, NPTEL AI‑enhanced MOOCs |\n| **Manufacturing & Logistics** | Predictive maintenance, demand forecasting, warehouse roboti ...

# %%
print(final_state['outline'])
# Out:
# **Blog Title:** *The Rise of AI in India: Opportunities, Challenges, and the Road Ahead*
#
# ---
#
# ## 1. Introduction
# - **Hook:** A striking statistic or anecdote (e.g., “India is projected to become the world’s third‑largest AI market by 2027.”)
# - **Why It Matters:** Briefly explain AI’s global impact and why India’s trajectory is uniquely significant.
# - **Thesis Statement:** Outline the blog’s focus – exploring the drivers, key players, sectoral adoption, policy landscape, challenges, and future outlook of AI in India.
#
# ---
#
# ## 2. Historical Context
# ### 2.1 Early Foundations
# - 1950s‑70s: Pioneering research at IITs & ISI Kolkata.
# - 1980s‑90s: Government-sponsored projects (e.g., C-DAC’s “Artificial Intelligence” labs).
#
# ### 2.2 The Turn‑of‑the‑Century Shift
# - Emergence of IT outsourcing and software services.
# - First wave of AI startups (e.g., Niramai, Haptik).
#
# ### 2.3 Post‑2015 Acceleration
# - Global AI boom + Indian government’s “Digital India” push.
# - Availability of cheap cloud compute and open‑source frameworks.
#
# ---
#
# ## 3. Key Drivers Behind the AI Surge
# | Driver | Description | Illustrative Example |
# |--------|-------------|----------------------|
# | **Demographic Dividend** | Young, tech‑savvy workforce; large talent pool. | 2.5 M+ engineering graduates annually. |
# | **Data Abundance** | Massive mobile penetration, digital payments, and government data portals. | Unified Payments Interface (UPI) generates billions of transactions daily. |
# | **Policy & Funding** | National AI Strategy, AI research grants, startup incentives. | NITI Aayog’s “AI for All” roadmap; INR 10,000 cr AI fund. |
# | **Corporate & Startup Ecosystem** | Presence of global tech giants and vibrant VC scene. | Google AI Research Center Bengaluru; $2 bn AI‑focused VC deals in 2023. |
# | **Infrastructure** | Cloud, 5G rollout, edge computing nodes. | Reliance Jio’s 5G network enabling real‑time AI services. |
#
# ---
#
# ## 4. Major Players & Ecosystem
# ### 4.1 Government & Public Institutions
# - **NITI Aayog** – AI strategy & task forces.
# - **DRDO & ISRO** – AI for defense, satellite imagery.
# - **IITs & IIMs** – AI research labs, interdisciplinary programs.
#
# ### 4.2 Corporate Leaders
# - **Tech Giants:** Google, Microsoft, Amazon, IBM (AI research labs in Bengaluru, Hyderabad).
# - **Indian Conglomerates:** Tata Consultancy Services, Infosys, Wipro (AI‑driven consulting & products).
#
# ### 4.3 Startup Landscape
# - **Healthcare:** Niramai (breast cancer screening), Qure.ai (radiology).
# - **FinTech:** Razorpay, Paytm (fraud detection, credit scoring).
# - **Agriculture:** CropIn, Stellapps (precision farming).
# - **Enterprise AI:** Mad Street Den, Uniphore (NLP & voice AI).
#
# ### 4.4 Funding & Investment Trends
# - Year‑on‑year VC/PE AI funding growth chart.
# - Notable exits & IPOs (e.g., Haptik acquisition by Reliance Jio).
#
# ---
#
# ## 5. Sector‑Specific AI Adoption
#
# | Sector | Use‑Cases | Impact Metrics | Notable Indian Initiatives |
# |--------|----------|----------------|----------------------------|
# | **Healthcare** | Diagnostic imaging, tele‑medicine bots, drug discovery | 30% reduction in diagnostic time; 20% cost savings | Niramai, HealthifyMe, AI‑enabled Ayushman Bharat portals |
# | **Finance & Banking** | Credit scoring, fraud detection, robo‑advisors | 40% drop in false‑positive fraud alerts | Paytm, Razorpay, Axis Bank’s AI‑driven chatbots |
# | **Agriculture** | Crop disease detection, yield prediction, supply‑chain optimization | 15% yield increase for pilot farms | CropIn, Stellapps, Microsoft’s AI for Earth India |
# | **Education** | Adaptive learning platforms, automated grading, language translation | 25% improvement in student engagement scores | BYJU’S AI, Embibe, NPTEL AI‑enhanced MOOCs |
# | **Manufacturing & Logistics** | Predictive maintenance, demand forecasting, warehouse robotics | 10–20% reduction in downtime | Tata Steel’s AI‑driven quality control, Delhivery’s route optimization |
# | **Public Services** | Smart cities, traffic management, citizen grievance bots | 12% reduction in traffic congestion in pilot cities | Smart Cities Mission AI pilots, Delhi Police’s AI surveillance |
#
# ---
#
# ## 6. Policy & Regulatory Landscape
#
# ### 6.1 National AI Strategy (NITI Aayog, 2018)
# - Vision, pillars (Research, Talent, Ecosystem, Ethics).
#
# ### 6.2 Data Governance & Privacy
# - Personal Data Protection Bill (PDPB) – implications for AI.
# - Data localization requirements for critical sectors.
#
# ### 6.3 AI Ethics & Responsible AI
# - NITI Aayog’s “Responsible AI” framework.
# - Emerging guidelines on bias mitigation, explainability, and accountability.
#
# ### 6.4 Incentives & Funding Mechanisms
# - AI Research Grants (Ministry of Electronics & IT).
# - Tax benefits for AI‑enabled R&D.
#
# ### 6.5 International Collaboration
# - Partnerships with OECD, EU AI Alliance, and US‑India AI initiatives.
#
# ---
#
# ## 7. Challenges & Bottlenecks
#
# | Challenge | Details | Potential Mitigation |
# |-----------|---------|----------------------|
# | **Talent Gap** | Shortage of senior AI researchers & data scientists. | Upskilling programs, AI‑focused PhDs, industry‑academia collaborations. |
# | **Data Quality & Access** | Fragmented data silos, lack of standardized datasets. | Open data portals, synthetic data generation, data trusts. |
# | **Infrastructure Disparities** | Rural‑urban divide in compute & connectivity. | Edge‑AI devices, 5G rollout, government cloud subsidies. |
# | **Ethical & Bias Concerns** | Socio‑cultural bias in language models, facial recognition. | Inclusive data collection, bias audits, regulatory oversight. |
# | **Regulatory Uncertainty** | Evolving data‑privacy laws may hinder innovation. | Clearer AI‑specific guidelines, sandbox environments. |
# | **Funding Gaps for Deep‑Tech** | Early‑stage AI research often under‑funded. | Dedicated deep‑tech funds, public‑private co‑investment models. |
#
# ---
#
# ## 8. Success Stories & Case Studies
#
# 1. **Niramai’s AI‑Based Breast Cancer Screening** – How a Bangalore startup reduced false‑positive rates and achieved FDA‑equivalent clearance.
# 2. **AI‑Powered Crop Monitoring by CropIn** – Impact on farmer incomes in Karnataka & Maharashtra.
# 3. **Microsoft & AI for Earth India** – Collaborative projects that saved water and increased yield for smallholder farms.
# 4. **Reliance Jio’s AI‑Driven Customer Service** – 70% reduction in call‑center handling time.
#
# *(Each case study can include problem, solution, technology stack, results, and lessons learned.)*
#
# ---
#
# ## 9. The Road Ahead: Future Outlook
#
# ### 9.1 Emerging Trends
# - **Generative AI & Large Language Models (LLMs)** – Localization of LLMs in Indian languages.
# - **AI‑Edge & IoT Convergence** – Smart agriculture drones, wearables for health monitoring.
# - **Quantum‑Ready AI** – Early research collaborations with Indian quantum labs.
#
# ### 9.2 Forecasts & Projections
# - Market size estimates (e.g., $30 bn by 2030).
# - Employment impact – creation of 2–3 million AI‑related jobs.
#
# ### 9.3 Strategic Recommendations
# - **For Policymakers:** Build a robust AI ethics board, streamline data‑sharing frameworks.
# - **For Corporates:** Invest in AI talent pipelines, adopt responsible AI practices.
# - **For Startups:** Focus on domain‑specific AI solutions, leverage government sandboxes.
# - **For Academia:** Expand interdisciplinary AI curricula, foster industry‑led research labs.
#
# ---
#
# ## 10. Conclusion
# - Recap of India’s rapid AI ascent and its transformative potential across sectors.
# - Emphasize the balance between innovation, ethical stewardship, and inclusive growth.
# - Call‑to‑action: Encourage readers (entrepreneurs, policymakers, students) to engage with the AI ecosystem—join hackathons, contribute to open‑source projects, or advocate for responsible AI policies.
#
# ---
#
# ## 11. Additional Elements (Optional)
#
# - **Infographics:** Timeline of AI milestones in India; ecosystem map of AI hubs (Bengaluru, Hyderabad, Pune, Delhi NCR).
# - **Quote Boxes:** Insights from NITI Aayog officials, startup founders, and global AI experts.
# - **Sidebar:** “Top 5 AI Courses & Certifications in India (2024)” – for readers looking to upskill.
# - **Resources & Further Reading:** Links to NITI Aayog AI strategy PDF, AI research labs, major AI conferences (e.g., AI India Summit).
#
# ---
#
# *End of Outline*

# %%
print(final_state['content'])
# Out:
# # **The Rise of AI in India: Opportunities, Challenges, and the Road Ahead**
#
# *By [Your Name] – AI Enthusiast & Technology Writer*
# *Date: June 8 2026*
#
# ---
#
# ## 1. Introduction
#
# > **“India is projected to become the world’s third‑largest AI market by 2027, with a valuation of over **$30 billion**.”** – NITI Aayog, 2024
#
# Artificial Intelligence is no longer a futuristic buzz‑word; it is reshaping economies, societies, and everyday life across the globe. For a country of 1.4 billion people, a burgeoning tech talent pool, and a digital ecosystem that processes **over 3 billion UPI transactions daily**, the AI story is uniquely Indian.
#
# In this blog we will:
#
# 1. Trace the historical roots of AI research in India.
# 2. Dissect the key drivers fueling the current surge.
# 3. Map the major players—government, corporates, and startups.
# 4. Examine sector‑specific adoption and measurable impact.
# 5. Decode the policy and regulatory framework.
# 6. Highlight the challenges that could stall momentum.
# 7. Celebrate success stories that illustrate what’s possible.
# 8. Look ahead to emerging trends and strategic recommendations.
#
# Let’s dive into how India is turning its demographic dividend, data abundance, and entrepreneurial spirit into a global AI powerhouse.
#
# ---
#
# ## 2. Historical Context
#
# ### 2.1 Early Foundations (1950s‑1970s)
# - **IITs & ISI Kolkata**: Pioneering work on pattern recognition, early neural‑network concepts, and symbolic AI.
# - **Key Figures**: Prof. S. S. Rao (IIT Kanpur) on fuzzy logic; Prof. B. B. Bose (ISI) on expert systems.
#
# ### 2.2 The Turn‑of‑the‑Century Shift (1980s‑1990s)
# - **C‑DAC’s “Artificial Intelligence” Labs**: Government‑funded labs in Pune and Hyderabad focused on speech recognition and natural language processing for Indian languages.
# - **IT Outsourcing Boom**: Indian software firms began offering AI‑adjacent services (rule‑based systems, data mining) to global clients.
#
# ### 2.3 Post‑2015 Acceleration
# - **Digital India & Mobile Revolution**: Smartphone penetration crossed 70 % in 2020, creating a flood of real‑time data.
# - **Open‑Source Explosion**: TensorFlow, PyTorch, and Hugging Face models became freely available, lowering entry barriers.
# - **Cloud Democratization**: AWS, Azure, Google Cloud, and home‑grown **IndiaStack** offered pay‑as‑you‑go compute, enabling startups to train models without massive capex.
#
# ---
#
# ## 3. Key Drivers Behind the AI Surge
#
# | **Driver** | **Description** | **Illustrative Example** |
# |------------|----------------|--------------------------|
# | **Demographic Dividend** | A youthful, English‑proficient workforce; 2.5 M+ engineering graduates each year, many with AI/ML specializations. | **IIT‑Bombay’s AI‑ML PhD program** now graduates 150 researchers annually. |
# | **Data Abundance** | Massive digital footprints from mobile usage, UPI, Aadhaar, and government portals. | **UPI** processes > 3 billion transactions/month, feeding fraud‑detection models. |
# | **Policy & Funding** | National AI Strategy, AI‑for‑All roadmap, dedicated INR 10,000 cr AI fund (≈ $120 bn). | **NITI Aayog’s AI Task Force** awarded ₹150 cr to 30 university labs in 2022. |
# | **Corporate & Startup Ecosystem** | Presence of global AI labs (Google, Microsoft) and a vibrant VC scene. | **Google AI Research Center Bengaluru** (opened 2021) collaborates with 12 Indian universities. |
# | **Infrastructure** | 5G rollout, edge‑computing nodes, and government cloud (MeghRaj). | **Reliance Jio’s 5G** enables real‑time video analytics for traffic management in Delhi. |
#
# These forces intersect to create a virtuous cycle: talent builds models → models generate value → value attracts investment → investment fuels more talent.
#
# ---
#
# ## 4. Major Players & Ecosystem
#
# ### 4.1 Government & Public Institutions
#
# | Institution | Role | Notable Initiatives |
# |-------------|------|---------------------|
# | **NITI Aayog** | Policy formulation, AI task forces, “AI for All” roadmap. | AI‑enabled health‑diagnosis pilots in 12 states. |
# | **DRDO & ISRO** | Defense & space AI (satellite imagery, autonomous drones). | **ISRO’s AI‑based crop‑health monitoring** for 5 M+ hectares. |
# | **IITs & IIMs** | Research labs, interdisciplinary AI curricula, incubators. | **IIT‑Madras Center for AI & Data Science (CAIDS)** – 200 cr research budget. |
# | **MeghRaj (Govt Cloud)** | Secure, sovereign cloud for AI workloads. | Hosts **National AI Platform** for public‑sector data sharing. |
#
# ### 4.2 Corporate Leaders
#
# - **Tech Giants** – Google AI Bengaluru, Microsoft AI & Research Hyderabad, Amazon AI (AWS) Delhi, IBM Research India (Bengaluru).
# - **Indian Conglomerates** – Tata Consultancy Services (TCS) AI‑Driven Consulting, Infosys Nia, Wipro HOLMES.
#
# These firms provide the backbone services (cloud, APIs, talent) that power most AI deployments across the country.
#
# ### 4.3 Startup Landscape
#
# | Domain | Startup | Core AI Solution | Impact |
# |--------|---------|------------------|--------|
# | **Healthcare** | **Niramai** | Thermal‑imaging + ML for breast‑cancer screening. | 0.5 % false‑positive rate; FDA‑equivalent clearance. |
# | **FinTech** | **Qure.ai** | Radiology‑report automation; **Razorpay** fraud‑detection engine. | 40 % reduction in false‑positive fraud alerts. |
# | **Agriculture** | **CropIn** | End‑to‑end farm‑data platform with predictive analytics. | 15 % yield boost for pilot farms in Karnataka. |
# | **Enterprise AI** | **Uniphore** | Conversational AI for call‑center automation. | 70 % reduction in average handling time. |
# | **EdTech** | **BYJU’S** | Adaptive learning powered by reinforcement learning. | 25 % improvement in student engagement scores. |
#
# ### 4.4 Funding & Investment Trends
#
# - **2021‑2024**: AI‑focused VC/PE funding grew **+84 % YoY**, reaching **$2.3 bn** in 2023 alone.
# - **Notable Exits**: **Haptik** (acquired by Reliance Jio for $300 m, 2022); **Mad Street Den** (Series C, $120 m, 2023).
# - **Deep‑Tech Funds**: Government‑backed **DeepTech India Fund** (₹5,000 cr) and private **Sequoia Surge AI** fund (₹2,500 cr).
#
# ---
#
# ## 5. Sector‑Specific AI Adoption
#
# | **Sector** | **Use‑Cases** | **Impact Metrics** | **Notable Indian Initiatives** |
# |------------|--------------|--------------------|--------------------------------|
# | **Healthcare** | Diagnostic imaging, AI‑chatbots, drug discovery, remote monitoring. | 30 % faster diagnosis; 20 % cost savings per patient. | Niramai, Qure.ai, AI‑enabled Ayushman Bharat portals. |
# | **Finance & Banking** | Credit scoring, AML/fraud detection, robo‑advisors, personalized offers. | 40 % drop in false‑positive fraud alerts; 15 % increase in loan approval speed. | Paytm, Razorpay, Axis Bank’s “Aditi” chatbot. |
# | **Agriculture** | Crop disease detection, yield forecasting, supply‑chain optimization, weather‑AI. | 15 % yield increase for pilot farms; 10 % reduction in post‑harvest loss. | CropIn, Stellapps, Microsoft AI for Earth India. |
# | **Education** | Adaptive learning, automated grading, language translation, virtual labs. | 25 % rise in student engagement; 12 % improvement in pass rates. | BYJU’S AI, Embibe, NPTEL AI‑enhanced MOOCs. |
# | **Manufacturing & Logistics** | Predictive maintenance, demand forecasting, robotic process automation, route optimization. | 10‑20 % reduction in downtime; 12 % lower logistics cost. | Tata Steel’s AI‑driven quality control, Delhivery’s AI routing. |
# | **Public Services** | Smart‑city traffic management, citizen grievance bots, AI‑enabled policing, disaster response. | 12 % reduction in traffic congestion in pilot cities; 30 % faster grievance resolution. | Smart Cities Mission AI pilots, Delhi Police AI surveillance. |
#
# > **Key Insight:** Across sectors, AI is delivering **double‑digit efficiency gains** while also unlocking new revenue streams—especially where data is abundant and the problem is well‑defined.
#
# ---
#
# ## 6. Policy & Regulatory Landscape
#
# ### 6.1 National AI Strategy (NITI Aayog, 2018)
# - **Vision:** Position India among the top three AI economies by 2030.
# - **Four Pillars:**
#   1. **Research & Development** – Funding for labs, open‑source platforms.
#   2. **Talent & Skilling** – AI‑ML curricula, reskilling of 500 k workers by 2025.
#   3. **Ecosystem & Infrastructure** – Cloud, data‑trusts, AI‑testbeds.
#   4. **Ethics & Governance** – Responsible AI framework, bias mitigation.
#
# ### 6.2 Data Governance & Privacy
#
# | Regulation | Status (2026) | AI Implications |
# |------------|---------------|-----------------|
# | **Personal Data Protection Bill (PDPB)** | Enacted (2025) – “Data fiduciary” concept. | AI models must embed privacy‑by‑design; stricter consent for personal data. |
# | **Data Localization** | Mandatory for banking, health, and critical infrastructure. | Encourages edge‑AI and on‑premise training; raises cost for global cloud providers. |
# | **Open Data Portals** | Government data (e.g., **Data.gov.in**) now includes standardized APIs for health, agriculture, and transport. | Faster prototyping for startups; reduces data‑silo friction. |
#
# ### 6.3 AI Ethics & Responsible AI
#
# - **NITI Aayog’s “Responsible AI” Framework (2022)** – 7 principles: fairness, transparency, accountability, privacy, robustness, sustainability, and inclusivity.
# - **AI Ethics Board** – Multi‑stakeholder body (academia, industry, civil society) that reviews high‑risk AI deployments (e.g., facial‑recognition in public spaces).
#
# ### 6.4 Incentives & Funding Mechanisms
#
# - **AI Research Grants** – ₹150 cr annually from the Ministry of Electronics & IT for university‑industry collaborations.
# - **Tax Benefits** – 150 % weighted deduction for AI‑related R&D expenses (effective FY 2025‑26).
# - **Sandbox Environments** – “AI Sandbox” in Bengaluru and Hyderabad where regulators allow limited‑scale testing of high‑risk AI under relaxed compliance.
#
# ### 6.5 International Collaboration
#
# - **OECD AI Policy Observatory** – India contributes to global AI standards.
# - **US‑India AI Initiative (2023)** – Joint research on AI for climate resilience.
# - **EU‑India AI Alliance (2024)** – Co‑development of multilingual LLMs.
#
# ---
#
# ## 7. Challenges & Bottlenecks
#
# | **Challenge** | **Details** | **Potential Mitigation** |
# |---------------|-------------|--------------------------|
# | **Talent Gap** | Shortage of senior AI researchers; brain‑drain to US/Europe. | Expand AI PhDs, industry‑academia joint labs, “AI Fellowships” funded by the government. |
# | **Data Quality & Access** | Fragmented silos, lack of labeled datasets for regional languages. | Create **Data Trusts** for agriculture & health; incentivize open‑source dataset contributions. |
# | **Infrastructure Disparities** | Rural areas still lack high‑speed broadband; compute clusters concentrated in metros. | Deploy **edge‑AI devices** (e.g., NVIDIA Jetson kits) via government subsidies; expand 5G to Tier‑2/3 cities. |
# | **Ethical & Bias Concerns** | Language models trained on English‑centric corpora; facial‑recognition bias against darker skin tones. | Enforce **bias‑audit mandates** for any AI product reaching > 1 M users; fund inclusive data‑collection drives. |
# | **Regulatory Uncertainty** | Ongoing revisions to PDPB and AI‑specific rules create compliance ambiguity. | Introduce **regulatory sandboxes** and clear AI‑specific guidelines (e.g., model‑card standards). |
# | **Funding Gaps for Deep‑Tech** | Early‑stage AI research (e.g., neuromorphic computing) struggles to attract VC. | Set up **government‑matched deep‑tech funds** and encourage corporate‑venture co‑investment. |
#
# ---
#
# ## 8. Success Stories & Case Studies
#
# ### 1. Niramai – AI‑Based Breast Cancer Screening
#
# - **Problem:** Conventional mammography is expensive, invasive, and has high false‑positive rates, especially in low‑resource settings.
# - **Solution:** Thermal
